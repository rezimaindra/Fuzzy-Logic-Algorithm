# %%
import pandas as pd
data = pd.read_excel('Mahasiswa.xls')

# %%
def fuzzyPemasukan(fuzzy):
  get = []
  getNilai = []
  if fuzzy <= 8 :
    for j in range(2):
      get.append(1)
      getNilai.append("Rendah")

  elif fuzzy > 8 and fuzzy < 9 :
    hasil = (fuzzy-8)/(9-8)
    get.append(hasil)
    getNilai.append("Cukup")
    hasil = (9-fuzzy)/(9-8)
    get.append(hasil)
    getNilai.append("Rendah")
      
  elif fuzzy >= 9 and fuzzy <= 14 :
    for j in range(2):
      get.append(1)
      getNilai.append("Cukup")

  elif fuzzy > 14 and fuzzy < 15 :
    hasil = (fuzzy-14)/(15-14)
    get.append(hasil)
    getNilai.append("Tinggi")
    hasil = (15-fuzzy)/(15-14)
    get.append(hasil)
    getNilai.append("Cukup")

  elif fuzzy >= 15 :
    for j in range(2):
      get.append(1)
      getNilai.append("Tinggi")
  
  valuePenghasilan.append(getNilai)
  return get

def fuzzyPengeluaran(fuzzy):
  get = []
  getNilai = []
  if fuzzy <= 3 :
    for j in range(2):
      get.append(1)
      getNilai.append("Kecil")

  elif fuzzy > 3 and fuzzy < 7 :
    hasil = (fuzzy-3)/(7-3)
    get.append(hasil)
    getNilai.append("Sedang")
    hasil = (7-fuzzy)/(7-3)
    get.append(hasil)
    getNilai.append("Kecil")
      
  elif fuzzy == 7:
    for j in range(2):
      get.append(1)
      getNilai.append("Sedang")

  elif fuzzy > 7 and fuzzy < 10 :
    hasil = (fuzzy-7)/(10-7)
    get.append(hasil)
    getNilai.append("Besar")
    hasil = (10-fuzzy)/(10-7)
    get.append(hasil)
    getNilai.append("Sedang")

  elif fuzzy >= 10 :
    for j in range(2):
      get.append(1)
      getNilai.append("Besar")

  valuePengeluaran.append(getNilai)    
  return get

def fuzzification(x):
  if flag == "red" :
    linguistik = []
    for i in range(len(x)) :
      nilai = x[i]
      linguistik.append(fuzzyPemasukan(nilai))
      

  if flag == "blue" :
    linguistik = []
    for i in range(len(x)) :
      nilai = x[i]
      linguistik.append(fuzzyPengeluaran(nilai))
      

  return linguistik

# %%
def inferenceA() :
  for i in range(len(valuePenghasilan)) :
    conjuction  = []
    valueConjuction = []
    
    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    # =====================================================================

    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Rendah" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Cukup" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][0] == "Tinggi" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][0] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][0])
      else:
        valueConjuction.append(LingPengeluaran[i][1])
    
    # ====================================================================
    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][0] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][0] == "Sedang" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][0] == "Besar" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][0]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][0])

    # ====================================================================

    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Rendah" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Cukup" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Tinggi")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][1] == "Kecil" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][1] == "Sedang" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    if valuePenghasilan[i][1] == "Tinggi" and valuePengeluaran[i][1] == "Besar" : 
      conjuction.append("Rendah")
      if LingPenghasilan[i][1] < LingPengeluaran[i][1]:
        valueConjuction.append(LingPenghasilan[i][1])
      else:
        valueConjuction.append(LingPengeluaran[i][1])

    minimum.append(conjuction)
    valueMinimum.append(valueConjuction)

# %%
def inferenceB() :
  for i in range(len(minimum)) :
    disjunction = []
    rendah = 0
    tinggi = 0
    j = 0

    for j in range(3) :
      if minimum[i][j] == "Rendah" :
        rendah = valueMinimum[i][j]
        if minimum[i][j+1] == "Rendah" and valueMinimum[i][j] < valueMinimum[i][j+1] :
          rendah = valueMinimum[i][j+1]
      elif minimum[i][j] == "Tinggi" :
        tinggi = valueMinimum[i][j]
        if minimum[i][j+1] == "Tinggi" and valueMinimum[i][j] < valueMinimum[i][j+1] :
          tinggi = valueMinimum[i][j+1]
    disjunction.append(rendah)
    disjunction.append(tinggi)

    maksimum.append(disjunction)

# %%
# tRendah = [10,20,30,40,50]
# tTinggi = [60,70,80,90,100]
# aTinggi = 40
# bTinggi = 60
# aRendah = 40
# bRendah = 50

# %%
# def pembilang(t,n):
#   jumlah = 0
#   for i in range(6):
#     jumlah += t[i]
#   hasil = jumlah * n
#   return hasil

# %%
# def nilaiX(n,a,b):
#   hasil = int(n * (b - a) + a)
#   return hasil

# %%
# def defuzzification() :
#   hasil = []
#   total = 0
#   for i in range(len(maksimum)):
#     if maksimum[i][0] = 0 or maksimum[i][1] = 0 :
#       if maksimum[i][0] = 0 :
#         x = nilaiX(maksimum[i][1],aTinggi,bTinggi)
#         i = 0
#         jumlah = 0
#         miuArr = []

#         while tTinggi[i] != x:
#           miu = (tTinggi - aTinggi)/(bTinggi-aTinggi)
#           miuArr.append(miu)
#           jumlah += (tTinggi * miu)
#           i += 1

        

#     else :
#       if maksimum[i][0] > maksimum[i][1] :
#         a = pembilang(tRendah,maksimum[i][0])
#         b = pembilang(tTinggi,maksimum[i][1])
#         c = 5 * maksimum[i][0] + 6 * maksimum[i][1]
#         total = (a + b)/n
      
#       else :
#         a = pembilang(tRendah,maksimum[i][0])
#         b = pembilang(tTinggi,maksimum[i][1])
#         c = 5 * maksimum[i][0] + 6 * maksimum[i][1]
#         total = (a + b)/n
#     hasil.append[total]

#     return hasil

# %%
def defuzzification() :
  get = []
  rendah = 40
  tinggi = 80
  for i in range(len(maksimum)):
    hasil = (maksimum[i][0] * rendah + maksimum[i][1] * tinggi)/ (maksimum[i][0] + maksimum[i][1])
    get.append(hasil)

  # get = []
  # rendah = 40
  # tinggi = 80
  # for i in range(len(maksimum)):
  #   b = maksimum[i][0] + maksimum[i][1]
  #   if b == 0 :
  #     b = 1
  #   hasil = (maksimum[i][0] * rendah + maksimum[i][1] * tinggi)/ b
  #   get.append(hasil)
  
  return get

# %%
PenghasilanArr = data["Penghasilan"]
PengeluaranArr = data["Pengeluaran"]
IdArr  = data["Id"]
valuePenghasilan = []
valuePengeluaran = []
minimum = []            # Conjuction
valueMinimum = []       # Nilai Conjuction
maksimum = []           # Disjunction
valueMaksimum = []      # Nilai Disjunction
NilaiKelayakan = []
indexNK = []


# red = penghasilan
# blue = Pengeluaran

print("Linguistik Penghasilan")
flag = "red" 
LingPenghasilan = fuzzification(PenghasilanArr)
print(LingPenghasilan)
print()
print(valuePenghasilan)
print("============================================\n")


print("Linguistik Pengeluaran")
flag = "blue"
LingPengeluaran = fuzzification(PengeluaranArr)
print(LingPengeluaran)
print()
print(valuePengeluaran)
print("============================================\n")

print("CONJUCTION")
inferenceA()
print(valueMinimum)
print()
print(minimum)
print()

print("DISJUNCTION")
# [rendah,tinggi]
print("[Rendah,Tinggi]")
inferenceB()
print(maksimum)
print()


print("NILAI KELAYAKAN")
NilaiKelayakan = defuzzification()
print()
print(NilaiKelayakan)
print()
# Out:
# ], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Cukup', 'Rendah'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Tinggi', 'Cukup'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Cukup'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Cukup', 'Rendah'], ['Rendah', 'Rendah'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Cukup', 'Rendah'], ['Tinggi', 'Tinggi'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Cukup'], ['Tinggi', 'Cukup'], ['Tinggi', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Cukup', 'Cukup'], ['Cukup', 'Cukup'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Tinggi'], ['Tinggi', 'Cukup'], ['Cukup', 'Cukup'], ['Rendah', 'Rendah']]
# ...

# %%
# IndexNilaiKelayakan = defuzzification()
# NA = dict(enumerate(NilaiKelayakan))

# print(NA)

# sort_NA = sorted(NA.items(), key = lambda x:x[1], reverse = True)
# # print(sort_NA)

# listIndex = []
# for i in range(len(sort_NA)):
#   listIndex.append(sort_NA[i][0]) 

# listIndexPenerima = []
# for i in range(len(listIndex[0:20])):
#     listIndex[i]+=1
#     listIndexPenerima.append(listIndex[i])
    

# listIndexPenerima.sort()
# for i in range(len(listIndexPenerima)):
#   print("Id Penerima Bantuan",listIndexPenerima[i])

# %%
data = pd.read_excel('Mahasiswa.xls')
data["NilaiKelayakan"] = NilaiKelayakan
data = data.sort_values("NilaiKelayakan",ascending= False)
print(data[:20])

data = pd.DataFrame(data.index.to_list(), columns=['Id'])[:20].to_excel("Bantuan.xlsx", index=False)
# Out:
#      Id  Penghasilan  Pengeluaran  NilaiKelayakan
# 12   13         5.55         6.35            80.0
# 24   25         6.48         7.85            80.0
# 32   33         7.03        10.11            80.0
# 80   81         9.18         9.46            80.0
# 35   36        13.92         7.20            80.0
# 36   37        13.52         9.46            80.0
# 37   38         9.94        10.82            80.0
# 78   79         8.52        10.32            80.0
# 40   41         4.62         6.88            80.0
# 45   46         9.58        10.04            80.0
# 46   47         9.63         9.78            80.0
# 48   49         9.52        10.93            80.0
# 99  100         7.84         3.44            80.0
# 49   50         9.31        11.29            80.0
# 51   52         9.10         9.57            80.0
# 75   76        12.17         7.20            80.0
# 74   75         5.09         7.53            80.0
# 55   56        13.81         9.25            80.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(data['Penghasilan'], data['Pengeluaran'], hue=data['NilaiKelayakan'])

fig, ax = plt.subplots(1, figsize=(12,6))

ax = sns.scatterplot(data[20:].Penghasilan, data[20:].Pengeluaran, label="Tidak dapat bantuan")
ax = sns.scatterplot(data[:20].Penghasilan, data[:20].Pengeluaran, label='Dapat bantuan')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
